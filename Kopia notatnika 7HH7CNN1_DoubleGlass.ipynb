# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.0)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 87.8 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 44.5 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.56.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 61.3 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Praktyki/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (256, 256),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(256, 256),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (256, 256),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', input_shape = (256,256,3), kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

#network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
#network.add(BatchNormalization())
#network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

#network.add(Dropout(0.2))
#network.add(Dense(units = 256, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  batch_normalization (BatchN  (None, 254, 254, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 127, 127, 64)      18496
#
#  conv2d_2 (Conv2D)           (None, 127, 127, 64)      36928
#
#  batch_normalization_1 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 63, 63, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 63, 63, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 63, 63, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 31, 31, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 123008)            0
#
#  batch_normalization_3 (Batc  (None, 123008)           492032
#  hNormalization)
#
#  dense (Dense)               (None, 128)               15745152
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_6 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 16,527,303
# Trainable params: 16,280,391
# Non-trainable params: 246,912
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# <ipython-input-18-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# 50/50 [==============================] - ETA: 0s - loss: 1.5222 - accuracy: 0.4540
# Epoch 1: val_accuracy improved from -inf to 0.24000, saving model to best_model1.h5
# 50/50 [==============================] - 212s 4s/step - loss: 1.5222 - accuracy: 0.4540 - val_loss: 3.3318 - val_accuracy: 0.2400 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2731 - accuracy: 0.5460
# Epoch 2: val_accuracy did not improve from 0.24000
# 50/50 [==============================] - 202s 4s/step - loss: 1.2731 - accuracy: 0.5460 - val_loss: 2.6747 - val_accuracy: 0.0800 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3666 - accuracy: 0.5240
# Epoch 3: val_accuracy improved from 0.24000 to 0.40000, saving model to best_model1.h5
# 50/50 [==============================] - 211s 4s/step - loss: 1.3666 - accuracy: 0.5240 - val_loss: 1.5366 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1512 - accuracy: 0.5780
# Epoch 4: val_accuracy did not improve from 0.40000
# 50/50 [==============================] - 205s 4s/step - loss: 1.1512 - accuracy: 0.5780 - val_loss: 2.1043 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0870 - accuracy: 0.6160
# Epoch 5: val_accuracy improved from 0.40000 to 0.56000, saving model to best_model1.h5
# 50/50 [==============================] - 204s 4s/step - loss: 1.0870 - accuracy: 0.6160 - val_loss: 1.3085 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0719 - accuracy: 0.6060
# Epoch 6: val_accuracy improved from 0.56000 to 0.60000, saving model to best_model1.h5
# 50/50 [==============================] - 212s 4s/step - loss: 1.0719 - accuracy: 0.6060 - val_loss: 1.0170 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0533 - accuracy: 0.6420
# Epoch 7: val_accuracy did not improve from 0.60000
# 50/50 [==============================] - 205s 4s/step - loss: 1.0533 - accuracy: 0.6420 - val_loss: 1.1961 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1655 - accuracy: 0.5880
# Epoch 8: val_accuracy improved from 0.60000 to 0.80000, saving model to best_model1.h5
# 50/50 [==============================] - 205s 4s/step - loss: 1.1655 - accuracy: 0.5880 - val_loss: 0.7473 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0857 - accuracy: 0.5840
# Epoch 9: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 208s 4s/step - loss: 1.0857 - accuracy: 0.5840 - val_loss: 1.0218 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8596 - accuracy: 0.7040
# Epoch 10: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 204s 4s/step - loss: 0.8596 - accuracy: 0.7040 - val_loss: 0.8288 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0325 - accuracy: 0.6600
# Epoch 11: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 208s 4s/step - loss: 1.0325 - accuracy: 0.6600 - val_loss: 0.7797 - val_accuracy: 0.7600 - lr: 0.0010
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8816 - accuracy: 0.6840
# Epoch 12: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 204s 4s/step - loss: 0.8816 - accuracy: 0.6840 - val_loss: 0.8653 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8913 - accuracy: 0.6680
# Epoch 13: val_accuracy did not improve from 0.80000
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 204s 4s/step - loss: 0.8913 - accuracy: 0.6680 - val_loss: 0.9193 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9327 - accuracy: 0.6760
# Epoch 14: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 211s 4s/step - loss: 0.9327 - accuracy: 0.6760 - val_loss: 0.9923 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9474 - accuracy: 0.6807
# Epoch 15: val_accuracy improved from 0.80000 to 0.82000, saving model to best_model1.h5
# 50/50 [==============================] - 205s 4s/step - loss: 0.9474 - accuracy: 0.6807 - val_loss: 0.6260 - val_accuracy: 0.8200 - lr: 5.0000e-04
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.7000
# Epoch 16: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 204s 4s/step - loss: 0.8571 - accuracy: 0.7000 - val_loss: 0.8903 - val_accuracy: 0.7400 - lr: 5.0000e-04
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8543 - accuracy: 0.7100
# Epoch 17: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 202s 4s/step - loss: 0.8543 - accuracy: 0.7100 - val_loss: 0.9822 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7963 - accuracy: 0.7120
# Epoch 18: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 204s 4s/step - loss: 0.7963 - accuracy: 0.7120 - val_loss: 0.8953 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7669 - accuracy: 0.7120
# Epoch 19: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 201s 4s/step - loss: 0.7669 - accuracy: 0.7120 - val_loss: 0.5938 - val_accuracy: 0.8200 - lr: 5.0000e-04
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.7420
# Epoch 20: val_accuracy did not improve from 0.82000
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 204s 4s/step - loss: 0.7211 - accuracy: 0.7420 - val_loss: 0.7315 - val_accuracy: 0.7400 - lr: 5.0000e-04
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.7060
# Epoch 21: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 202s 4s/step - loss: 0.8055 - accuracy: 0.7060 - val_loss: 0.5516 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8001 - accuracy: 0.7200
# Epoch 22: val_accuracy improved from 0.82000 to 0.88000, saving model to best_model1.h5
# 50/50 [==============================] - 205s 4s/step - loss: 0.8001 - accuracy: 0.7200 - val_loss: 0.4358 - val_accuracy: 0.8800 - lr: 2.5000e-04
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7938 - accuracy: 0.7040
# Epoch 23: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 201s 4s/step - loss: 0.7938 - accuracy: 0.7040 - val_loss: 0.5202 - val_accuracy: 0.8600 - lr: 2.5000e-04
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8095 - accuracy: 0.7200
# Epoch 24: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 204s 4s/step - loss: 0.8095 - accuracy: 0.7200 - val_loss: 0.6090 - val_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7119 - accuracy: 0.7580
# Epoch 25: val_accuracy improved from 0.88000 to 0.92000, saving model to best_model1.h5
# 50/50 [==============================] - 209s 4s/step - loss: 0.7119 - accuracy: 0.7580 - val_loss: 0.4258 - val_accuracy: 0.9200 - lr: 2.5000e-04
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7581 - accuracy: 0.7300
# Epoch 26: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 202s 4s/step - loss: 0.7581 - accuracy: 0.7300 - val_loss: 0.5861 - val_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8501 - accuracy: 0.6900
# Epoch 27: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 201s 4s/step - loss: 0.8501 - accuracy: 0.6900 - val_loss: 0.6671 - val_accuracy: 0.7400 - lr: 2.5000e-04
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.7200
# Epoch 28: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 200s 4s/step - loss: 0.7525 - accuracy: 0.7200 - val_loss: 0.4238 - val_accuracy: 0.8400 - lr: 2.5000e-04
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7578 - accuracy: 0.7220
# Epoch 29: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 198s 4s/step - loss: 0.7578 - accuracy: 0.7220 - val_loss: 0.4089 - val_accuracy: 0.8600 - lr: 2.5000e-04
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7136 - accuracy: 0.7480
# Epoch 30: val_accuracy did not improve from 0.92000
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 200s 4s/step - loss: 0.7136 - accuracy: 0.7480 - val_loss: 0.5444 - val_accuracy: 0.8200 - lr: 2.5000e-04
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.7200
# Epoch 31: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 198s 4s/step - loss: 0.7231 - accuracy: 0.7200 - val_loss: 0.5236 - val_accuracy: 0.8800 - lr: 1.2500e-04
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7313 - accuracy: 0.7320
# Epoch 32: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 200s 4s/step - loss: 0.7313 - accuracy: 0.7320 - val_loss: 0.4087 - val_accuracy: 0.9000 - lr: 1.2500e-04
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.7249
# Epoch 33: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 198s 4s/step - loss: 0.7520 - accuracy: 0.7249 - val_loss: 0.5840 - val_accuracy: 0.8600 - lr: 1.2500e-04
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6995 - accuracy: 0.7540
# Epoch 34: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 199s 4s/step - loss: 0.6995 - accuracy: 0.7540 - val_loss: 0.4940 - val_accuracy: 0.8400 - lr: 1.2500e-04
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6547 - accuracy: 0.7760
# Epoch 35: val_accuracy did not improve from 0.92000
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 201s 4s/step - loss: 0.6547 - accuracy: 0.7760 - val_loss: 0.4928 - val_accuracy: 0.8400 - lr: 1.2500e-04
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.7600
# Epoch 36: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 200s 4s/step - loss: 0.6904 - accuracy: 0.7600 - val_loss: 0.3632 - val_accuracy: 0.9000 - lr: 6.2500e-05
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6294 - accuracy: 0.7660
# Epoch 37: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 202s 4s/step - loss: 0.6294 - accuracy: 0.7660 - val_loss: 0.5398 - val_accuracy: 0.8400 - lr: 6.2500e-05
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.7520
# Epoch 38: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 199s 4s/step - loss: 0.6710 - accuracy: 0.7520 - val_loss: 0.4873 - val_accuracy: 0.8200 - lr: 6.2500e-05
# Epoch 39/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.7751
# Epoch 39: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 201s 4s/step - loss: 0.6452 - accuracy: 0.7751 - val_loss: 0.5357 - val_accuracy: 0.8400 - lr: 6.2500e-05
# Epoch 40/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.7680
# Epoch 40: val_accuracy did not improve from 0.92000
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 199s 4s/step - loss: 0.6799 - accuracy: 0.7680 - val_loss: 0.3890 - val_accuracy: 0.8400 - lr: 6.2500e-05
# Epoch 41/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7210 - accuracy: 0.7460
# Epoch 41: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 201s 4s/step - loss: 0.7210 - accuracy: 0.7460 - val_loss: 0.3709 - val_accuracy: 0.8600 - lr: 3.1250e-05
# Epoch 42/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.8100
# Epoch 42: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 201s 4s/step - loss: 0.6009 - accuracy: 0.8100 - val_loss: 0.4567 - val_accuracy: 0.8600 - lr: 3.1250e-05
# Epoch 43/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.7880
# Epoch 43: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 202s 4s/step - loss: 0.6260 - accuracy: 0.7880 - val_loss: 0.5144 - val_accuracy: 0.8200 - lr: 3.1250e-05
# Epoch 44/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6652 - accuracy: 0.7640
# Epoch 44: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 200s 4s/step - loss: 0.6652 - accuracy: 0.7640 - val_loss: 0.4302 - val_accuracy: 0.9000 - lr: 3.1250e-05
# Epoch 45/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.7580
# Epoch 45: val_accuracy did not improve from 0.92000
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 203s 4s/step - loss: 0.6569 - accuracy: 0.7580 - val_loss: 0.4812 - val_accuracy: 0.8400 - lr: 3.1250e-05
# Epoch 45: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.8438395415472779

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       198
#            1       0.97      1.00      0.98       200
#            2       0.72      0.84      0.78       200
#            3       0.73      0.54      0.62       199
#            4       0.85      0.92      0.88       200
#            5       0.85      0.71      0.77       199
#            6       0.87      0.92      0.90       200
#
#     accuracy                           0.84      1396
#    macro avg       0.84      0.84      0.84      1396
# weighted avg       0.84      0.84      0.84      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 157s 112ms/step - loss: 0.5625 - accuracy: 0.8216
# [0.5624936819076538, 0.8216332197189331]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       198
#            1       0.99      0.99      0.99       200
#            2       0.68      0.80      0.73       200
#            3       0.78      0.41      0.54       199
#            4       0.82      0.91      0.86       200
#            5       0.77      0.75      0.76       199
#            6       0.80      0.93      0.86       200
#
#     accuracy                           0.82      1396
#    macro avg       0.82      0.82      0.81      1396
# weighted avg       0.82      0.82      0.81      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 158s 113ms/step - loss: 0.4891 - accuracy: 0.8438
# [0.4891465902328491, 0.8438395261764526]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       198
#            1       0.99      0.99      0.99       200
#            2       0.68      0.80      0.73       200
#            3       0.78      0.41      0.54       199
#            4       0.82      0.91      0.86       200
#            5       0.77      0.75      0.76       199
#            6       0.80      0.93      0.86       200
#
#     accuracy                           0.82      1396
#    macro avg       0.82      0.82      0.81      1396
# weighted avg       0.82      0.82      0.81      1396
